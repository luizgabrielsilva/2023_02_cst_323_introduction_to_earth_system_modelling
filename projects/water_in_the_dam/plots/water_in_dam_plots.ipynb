# %% [markdown]
# # Water in the Dam - Plots
#
#
# Notebook utilizado para plotar os gráficos das simulações

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

import pathlib

# %%
project_path = pathlib.Path().parent.resolve().parent
data_path = project_path/ pathlib.Path("data")

# %% [markdown]
# ## Precipitação
#
# São Paulo - Estação Mirante de Santana
#
# Normal climatológica 1991-2020 -
# https://clima.inmet.gov.br/GraficosClimatologicos/SP/83781
#
#
# São José dos Campos
#
# Normal Climatológica 1961-1990 -
# https://clima.inmet.gov.br/GraficosClimatologicos/SP/83809

# %%
data_sao_paulo = pd.read_csv(data_path / pathlib.Path("pluviometry/sao_paulo_pluviometria.csv"))
data_sao_jose = pd.read_csv(data_path / pathlib.Path("pluviometry/sao_jose_dos_campos_pluviometria.csv"))

# %%
data_sao_paulo.head()
# Out:
#        Month  1991 - 2020      %
# 0    Janeiro        292.1  0.176
# 1  Feveveiro        257.7  0.155
# 2      Março        229.1  0.138
# 3      Abril         87.0  0.052
# 4       Maio         66.3  0.040

# %%
data_sao_jose.head()
# Out:
#        Month  1961 - 1990      %
# 0    Janeiro        192.5  0.167
# 1  Feveveiro        151.2  0.131
# 2      Março        132.8  0.115
# 3      Abril         59.8  0.052
# 4       Maio         30.3  0.026

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 5))

ax.plot(data_sao_paulo["Month"],
        data_sao_paulo["%"],
        "--o",
        color="blue",
        markerfacecolor="none",
        label="São Paulo (1991-2020)")

ax.plot(data_sao_jose["Month"],
        data_sao_jose["%"],
        "--o",
        color="violet",
        markerfacecolor="none",
        label="São José dos Campos (1961-1990)")

ax.set_xlabel("Mês")
ax.set_ylabel("Fração da precipitação")

ax.legend()

plt.show()

# %% [markdown]
# ## Testes

# %%
first_year = 15
last_year = 30

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,5))

for i, j in zip(["0.1", "0.2", "1.0"], [1, 2, 12]):
    tmp = pd.read_csv(data_path / pathlib.Path("water_in_dam_v" + i + "/waterDam_v_" + i + "_sim_1.csv"),
                      header=0, names=["water_vol"])

    ax.plot(tmp.index[first_year * j : last_year * j] / j + 1950,
            tmp.water_vol[first_year * j : last_year * j], "--o",
            markerfacecolor="none", label="Water Dam " + i, linewidth=0.8, markersize=3)


ax.legend()
ax.set_ylabel("Water Volume in the Dam (m³)")
ax.set_xlabel("Year")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 7
#       4 fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,5))
#       6 for i, j in zip(["0.1", "0.2", "1.0"], [1, 2, 12]):
# ----> 7     tmp = pd.read_csv(data_path / pathlib.Path("water_in_dam_v" + i + "/waterDam_v_" + i + "_sim_1.csv"),
#       8                       header=0, names=["water_vol"])
#      10     ax.plot(tmp.index[first_year * j : last_year * j] / j + 1950,
#      11             tmp.water_vol[first_year * j : last_year * j], "--o",
#      12             markerfacecolor="none", label="Water Dam " + i, linewidth=0.8, markersize=3)
#      15 ax.legend()
#
# File ~\miniconda3\envs\water_in_dam\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\miniconda3\envs\water_in_dam\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\miniconda3\envs\water_in_dam\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\miniconda3\envs\water_in_dam\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\miniconda3\envs\water_in_dam\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\PC-INPE\\Documents\\pgser\\2023_02\\2023_02_cst_323_introduction_to_earth_system_modelling\\projects\\water_in_the_dam\\data\\water_in_dam_v0.1\\waterDam_v_0.1_sim_1.csv'

# %% [markdown]
# ## Simulações

# %%
ref_year = 1950

colors = [
    "violet",
    "blue",
    "green",
    "orange",
    "red",
]

first_year = 15
last_year = 60

sim_time = [30, 25, 35, 55, 40]

# %% [markdown]
# ### Water In the Dam v0.1

# %%
m = 1
version = "0.1"

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,5))

for sim, time in zip(range(0, 5), sim_time):
    tmp = pd.read_csv(data_path / pathlib.Path("water_in_dam_v" + version
                                               + "/waterDam_v_" + version + "_sim_" + str(sim + 1) + ".csv"),
                      header=0, names=["water_vol"])

    ax.plot(tmp.index[first_year * m : time * m] / m + ref_year,
            tmp.water_vol[first_year * m : time * m], "--o",color=colors[sim],
            markerfacecolor="none", label="Sim " + str(sim + 1), linewidth=0.5, markersize=4)


ax.legend()
ax.set_ylabel("Water Volume in the Dam (m³)")
ax.set_xlabel("Year")

plt.show()

# %% [markdown]
# ### Water In the Dam v0.2

# %%
m = 2
version = "0.2"

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,5))

for sim, time in zip(range(0, 5), sim_time):
    tmp = pd.read_csv(data_path / pathlib.Path("water_in_dam_v" + version
                                               + "/waterDam_v_" + version + "_sim_" + str(sim + 1) + ".csv"),
                      header=0, names=["water_vol"])

    ax.plot(tmp.index[first_year * m : time * m] / m + ref_year,
            tmp.water_vol[first_year * m : time * m], "--o",color=colors[sim],
            markerfacecolor="none", label="Sim " + str(sim + 1), linewidth=0.5, markersize=3)


ax.legend()
ax.set_ylabel("Water Volume in the Dam (m³)")
ax.set_xlabel("Year")

plt.show()

# %% [markdown]
# ### Water In the Dam v1.0

# %%
m = 12
version = "1.0"

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(10,5))

for sim, time in zip(range(0, 5), sim_time):
    tmp = pd.read_csv(data_path / pathlib.Path("water_in_dam_v" + version
                                               + "/waterDam_v_" + version + "_sim_" + str(sim + 1) + ".csv"),
                      header=0, names=["water_vol"])

    ax.plot(tmp.index[first_year * m : time * m] / m + ref_year,
            tmp.water_vol[first_year * m : time * m], "--o",color=colors[sim],
            markerfacecolor="none", label="Sim " + str(sim + 1), linewidth=0.5, markersize=1)


ax.legend()
ax.set_ylabel("Water Volume in the Dam (m³)")
ax.set_xlabel("Year")

plt.show()
