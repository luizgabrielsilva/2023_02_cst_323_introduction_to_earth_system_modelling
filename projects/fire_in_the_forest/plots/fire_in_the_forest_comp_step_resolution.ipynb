# %% [markdown]
# # Experiment comparison

# %%
from matplotlib import pyplot as plt

import pathlib
from experiment import Experiment

# %%
project_path = pathlib.Path().parent.resolve().parent

# %%
# Parameters
exp1_params = dict(
    experiment_name="step=0.02",
    filename="resultado_teste_dim50_rep50.csv",
    project_path=project_path,
    dimension=50,
    color="red",
    expected_forest=True,
)

exp2_params = dict(
    experiment_name="step=0.05",
    filename="resultado_teste_dim50_rep50_step005.csv",
    project_path=project_path,
    dimension=50,
    color="blue",
    expected_forest=False,
)

experiments = [exp1_params, exp2_params]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5,5))

for experiment in experiments:
    Exp = Experiment(experiment_name=experiment["experiment_name"],
                     project_path=experiment["project_path"],
                     filename=experiment["filename"],
                     dimension=experiment["dimension"])
    
    Exp.get_data()
    Exp.process_data()
    
    Exp.plot_results(expected_forest=experiment["expected_forest"],
                     color=experiment["color"],
                     label=experiment["experiment_name"],
                     ax=ax)
